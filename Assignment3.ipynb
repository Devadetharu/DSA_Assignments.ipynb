# %% [markdown]
# <a href="https://colab.research.google.com/github/Devadetharu/Assignment3.ipynb/blob/main/Assignment3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Practice Problems

# %% [markdown]
# 1. Write a Python program which accepts the radius of a circle from the user and compute the area.
# Sample input: Enter the radius: 3
# Sample output: Area of Circle is 28.59999999999

# %%
radius = float(input("Enter the radius: "))
area = 3.14 * radius ** 2
print("Area of circle is",area)
# Out:
# Enter the radius: 3
# Area of circle is 28.26

# %% [markdown]
# 2. Write a Python Program to accept the details of a student like name, roll
# number and mark and display it.
# Sample input: Enter the name: Anisha
# Enter the roll number: 21
# Enter the mark: 78
# Sample output: Name: Anisha
# Roll No: 21
# Mark: 78

# %%
name = input("Enter the name: ")
roll_no = input("Enter the roll number: ")
mark = input("Enter the mark: ")

print(f"Name: {name}")
print(f"Roll no: {roll_no}")
print(f"Mark: {mark}")
# Out:
# Enter the name: Devadetharu
# Enter the roll number: 21
# Enter the mark: 78
# Name: Devadetharu
# Roll no: 21
# Mark: 78

# %% [markdown]
# 3. Write a Python program to get the largest number from a list.
# Sample input: 12, 3, 47, 10
# Sample output: 47 is the largest number.

# %%
numbers = [12,3,47,10]
largest = max(numbers)

print(f"{largest} is the largest number.")
# Out:
# 47 is the largest number.

# %% [markdown]
# 4. Given a range of first 10 numbers, write a Python program to iterate from start number to the end number and print the sum of the current number and previous number.
# Sample input: 1….10
# Sample output: Current Number 1 Previous Number 0 Sum: 1 Current Number 2 Previous Number 1 Sum: 3 Current Number 3 Previous Number 2 Sum: 5… Current Number 10 Previous Number 9 Sum: 19

# %%
previous = 0

for current in range(1,11):
  total = current + previous
  print("Current numbers:",current, "Previous number:",previous, "Sum:", total)
  previous = current
# Out:
# Current numbers: 1 Previous number: 0 Sum: 1
# Current numbers: 2 Previous number: 1 Sum: 3
# Current numbers: 3 Previous number: 2 Sum: 5
# Current numbers: 4 Previous number: 3 Sum: 7
# Current numbers: 5 Previous number: 4 Sum: 9
# Current numbers: 6 Previous number: 5 Sum: 11
# Current numbers: 7 Previous number: 6 Sum: 13
# Current numbers: 8 Previous number: 7 Sum: 15
# Current numbers: 9 Previous number: 8 Sum: 17
# Current numbers: 10 Previous number: 9 Sum: 19

# %% [markdown]
# 5. Write a Python program to print only those numbers which are divisible of 5.
# Sample input: 10, 20,33,46,55 Sample output: 10, 20, 55

# %%
numbers = [10,20,33,46,55]

for n in numbers:
  if n % 5 == 0:
    print(n)
# Out:
# 10
# 20
# 55

# %% [markdown]
# 6. Write a Python program to check whether a number is prime or not. Sample input: Enter the number: 3
# Sample output: 3 is a prime number.

# %%
num = int(input("Enter the number: "))

if num > 1:
  for i in range(2, num):
    if num % i == 0:
      print(f"{num} is not a prime number")
      break
  else:
    print(f"{num} is a prime number")
else:
    print(f"{num} is not a prime number")
# Out:
# Enter the number: 3
# 3 is a prime number

# %% [markdown]
# 7. Write a Python program to reverse a list using for loop.
# Sample input: 10,40,30,70
# Sample output: 70,30,40,10

# %%
numbers =[10,40,30,70]
reversed_list = []

for i in range(len(numbers) -1, -1, -1):
  reversed_list.append(numbers[i])
print("Reversed List:", reversed_list)
# Out:
# Reversed List: [70, 30, 40, 10]

# %% [markdown]
# 8. Write a Python program to print the following pattern

# %%
for i in range(1,5):
  print("*" *i)
# Out:
# *
# **
# ***
# ****

# %% [markdown]
# 9. Write a Python program to find the maximum of three numbers
# Sample input: 34,12,7
# Sample output: 34

# %%
a = 34
b = 12
c = 7

max = a

if a >= b and a >= c:
  print (a)
elif b >= a and b>= c:
  print (b)
else:
  print (c)
# Out:
# 34

# %% [markdown]
# 10. Write a Python program to construct the following pattern, using a nested for loop.

# %%
for i in range (1,6):
  for j in range (i):
    print("*", end="")
  print()

for i in range (4,0,-1):
  for j in range (i):
    print("*", end="")
  print()
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# # Practice_problems01

# %% [markdown]
# 1. Write a Python program that takes an integer as input and calculates the sum of its digits

# %%
num = input("Enter the number: ")
total = 0

for digit in num:
  total += int(digit)

print("Sum of its digits:", total)
# Out:
# Enter the number: 50
# Sum of its digits: 5

# %% [markdown]
# 2. Create a Python program to calculate the factorial of a given number using a function.

# %%
def factorial(n):
  if n == 0 or n == 1:
    return 1
  else:
    return n * factorial(n-1)

num = int(input("Enter a number: "))
print("Factorial of",num, "is", factorial(num))
# Out:
# Enter a number: 3
# Factorial of 3 is 6

# %% [markdown]
# 3. Develop a Python program that checks whether a given word or phrase is a palindrome.

# %%
text = input("Enter a word or phrase: ")

cleaned = text.replace(" ", "").lower()

if cleaned == cleaned[::-1]:
  print(f"'{text}' is a palindrome.")
else:
  print(f"'{text}' is not a palindrome.")
# Out:
# Enter a word or phrase: Malayalam
# 'Malayalam' is a palindrome.

# %% [markdown]
# 4. Create a Python program that takes a sentence as input and counts the number of vowels and consonants.

# %%
sentence = input("Enter a sentence: ")
vowels = "aeiou"
vowel_count = 0
consonant_count = 0

for char in sentence:
  if char.isalpha():
    if char in vowels:
      vowel_count += 1
    else:
      consonant_count += 1

print("Number of vowels :", vowel_count)
print("Number of consonants :", consonant_count)
# Out:
# Enter a sentence: Hi there! How are you
# Number of vowels : 8
# Number of consonants : 8

# %% [markdown]
# 5. Develop a Python program that takes two lists as input and returns a new list containing the common elements between them.

# %%
list1 = input("Enter the first list (comma-separated): ")
list2 = input("Enter the second list (comma-separated): ")

list1 = [int(x) for x in list1.split(",")]
list2 = [int(x) for x in list2.split(",")]

common = list(set(list1) & set(list2))

print("Common Elements:", common)
# Out:
# Enter the first list (comma-separated): 1,3,5,7,9
# Enter the second list (comma-separated): 8,6,7,4,3
# Common Elements: [3, 7]

# %% [markdown]
# 6. Write a Python program that takes a string as input and counts the frequency of each character in the string.

# %%
text = input("Enter a string : ")

freq  = {}

for char in text:
  if char in freq:
    freq[char] += 1
  else:
    freq[char] = 1

for char, count in freq.items():
  print(f"'{char}' : {count}")
# Out:
# Enter a string : Malayalam
# 'M' : 1
# 'a' : 4
# 'l' : 2
# 'y' : 1
# 'm' : 1

# %% [markdown]
# 7. Develop a Python program that checks if a given year is a leap year.

# %%
year = int(input("Enter a year : "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
  print(year, "is a leap year.")
else:
  print(year, "is not a leap year.")
# Out:
# Enter a year : 2020
# 2020 is a leap year.

# %% [markdown]
# 8. Write a Python program that checks if a given number, is a prime number.

# %%
num = int(input("Enter a number: "))

if num <= 1:
  print(num, "is not a prime number.")
else:
  is_prime = True
  for i in range(2, int(num ** 0.5) + 1):
    if num % i == 0:
      is_prime = False
      break
  if is_prime:
    print(num, "is a prime number.")
  else:
    print(num, "is not a prime number.")
# Out:
# Enter a number: 7
# 7 is a prime number.

# %% [markdown]
# 9. Write a Python program to generate the Fibonacci sequence up to a specified number of terms.

# %%
n = int(input("Enter the number of terms: "))

a , b = 0 , 1

for i in range(n):
  print(a, end=" ")
  a , b = b, a + b
# Out:
# Enter the number of terms: 5
# 0 1 1 2 3

# %% [markdown]
# 10. Write a python program to find the roots of a quadratic equation

# %%
import cmath
a = float(input("Enter coefficient a: "))
b = float(input("Enter coefficient b: "))
c = float(input("Enter coefficient c: "))

D = b**2 - 4*a*c

root1 = (-b + cmath.sqrt(D)) / (2 * a)
root2 = (-b + cmath.sqrt(D)) / (2 * a)

print("Root 1:", root1)
print("Root 2:", root2)
# Out:
# Enter coefficient a: 1
# Enter coefficient b: -4
# Enter coefficient c: 3
# Root 1: (3+0j)
# Root 2: (3+0j)

# %% [markdown]
# # Python Practice Problems 2

# %% [markdown]
# 1. Write a Python program to accept a string value from the user and display the count of each character in that string. Sample input: Enter a string value: assembly Sample output: a=1, s=2, e=1, m=1, b=1, l=1, y=1

# %%
text = input("Enter a string value: ")

freq = {}

for char in text:
  freq[char] = freq.get(char, 0) + 1

output = []
for char in sorted(freq.keys()):
  output.append(f"{char}={freq[char]}")

print(", ".join(output))
# Out:
# Enter a string value: Devadetharu
# D=1, a=2, d=1, e=2, h=1, r=1, t=1, u=1, v=1

# %% [markdown]
# 2. Write a Python function to find the maximum of three numbers Sample input: 34,12,7 Sample output: 34

# %%
def max_of_three(a,b,c):
  if a >= b and a >= c:
    return a
  elif b >= a and b >= c:
    return b
  else:
    return c

print(max_of_three(34,12,7))
# Out:
# 34

# %% [markdown]
# 3. Write a Python function called exponent(base,exp) that returns an integer value of base raises to the power of exp. Sample input: Enter the base: 2 Enter the exponent: 3 Sample output: 8

# %%
def exponent(base, exp):
  result = 1
  for i in range(exp):
    result *= base
  return result

base = int(input("Enter the base: "))
exp = int(input("Enter the exponents: "))

print(exponent(base, exp))
# Out:
# Enter the base: 2
# Enter the exponents: 3
# 8

# %% [markdown]
# 4. Write a Python function that takes a positive integer and returns the sum of the cube of all the positive integers smaller than the specified number. Sample input: 4 Sample output: 36.

# %%
def sum_of_cubes(n):
  total = 0
  for i in range(1, n):
    total += i**3
  return total

num = 4
print(sum_of_cubes(num))
# Out:
# 36

# %% [markdown]
# 5. Write a Python program which iterates from 1 to 10. For multiples of 2, print “Fizz” instead of the number and for the multiples of 5, print “Buzz”. For numbers which are multiples of both 2 and 5, print “FizzBuzz”. Sample input: numbers from 1 to 10 Sample output: 1 Fizz 3 Fizz Buzz Fizz 7 Fizz 9 FizzBuzz

# %%
for i in range(1,11):
  if i % 2 == 0 and i % 5 == 0:
    print("FizzBuzz")
  elif i % 2 == 0:
    print("Fizz")
  elif i % 5 == 0:
    print("Buzz")
  else:
    print(i)
# Out:
# 1
# Fizz
# 3
# Fizz
# Buzz
# Fizz
# 7
# Fizz
# 9
# FizzBuzz

# %% [markdown]
# 6. Write a Python program to find the most frequent item in a list of numbers. Sample input: 2, 3, 4, 2, 5, 2 Sample output: 2

# %%
numbers = list(map(int, input("Enter numbers seperated by comma: ").split(",")))

freq = {}

for num in numbers:
    freq[num] = freq.get(num, 0) + 1

sorted_freq = sorted(freq.items(), key=lambda x: x[1], reverse=True)

most_frequent = sorted_freq[0][0]

print("\nFrequency of each number (sorted by frequency):")
for num, count in freq.items():
  print(f"{num} -> {count} time(s)")

print("\nMost frequent number is:", most_frequent)
# Out:
# Enter numbers seperated by comma: 2, 3, 4, 2, 5, 2
#
# Frequency of each number (sorted by frequency):
# 2 -> 3 time(s)
# 3 -> 1 time(s)
# 4 -> 1 time(s)
# 5 -> 1 time(s)
#
# Most frequent number is: 2

# %% [markdown]
# 7. Write a Python program to find the sum of squares of the numbers in a list. Sample input: 2,1,3,1 Sample output: 15

# %%
numbers = list(map(int, input("Enter numbers seperated by comma:").split(",")))

total = 0
for num in numbers:
  total += num ** 2

print("Sum of squares is: ",total)
# Out:
# Enter numbers seperated by comma:2, 1, 3, 1
# Sum of squares is:  15

# %% [markdown]
# 8. Write a Python program using for loop that will iterate from 1 to 15. For each iteration, check if the current number is odd or even, and display the message to the screen as odd or even. Sample input: 1….15 Sample output: 1-odd 2-even …. 15-odd

# %%
for i in range(1,16):
  if i % 2 == 0:
    print(f"{i} - even")
  else:
    print(f"{i} - odd")
# Out:
# 1 - odd
# 2 - even
# 3 - odd
# 4 - even
# 5 - odd
# 6 - even
# 7 - odd
# 8 - even
# 9 - odd
# 10 - even
# 11 - odd
# 12 - even
# 13 - odd
# 14 - even
# 15 - odd

# %% [markdown]
# 9. Write a Python program to convert temperatures to and from Celsius Fahrenheit. [Formula: c/5=f-32/9 where c=temperature in Celsius and f= temperature in Fahrenheit.] Sample input: Temperature in Fahrenheit =41 Sample output: Temperature in Celsius =5

# %%
print("1. convert fahrenheit to celsius")
print("2. convert celsius to fahrenheit")

choice = int(input("Enter your choice (1 or 2): "))

if choice == 1:
  f = float(input("Enter temperature in fahrenheit: "))
  c = (f - 32) * 5/9
  print(f"Temperature in celsius=", round(c, 2))

elif choice == 2:
  c = float(input("Enter temperature in celsius: "))
  f = (c * 9/5) + 32
  print(f"Temperature in fahrenheit=", round(f, 2))

else:
  print("Invalid choice!")
# Out:
# 1. convert fahrenheit to celsius
# 2. convert celsius to fahrenheit
# Enter your choice (1 or 2): 1
# Enter temperature in fahrenheit: 41
# Temperature in celsius= 5.0

# %% [markdown]
# 10. Write a Python function to calculate the factorial of a number (a nonnegative integer). The function accepts the number as an argument. Sample input: 3 Sample output: 6

# %%
def factorial (n):
  if n == 0 or n == 1:
    return 1
  else:
    return n * factorial(n-1)

num = int(input("Enter a non negative integer: "))
if num < 0:
  print("Factorial is not defined for negative numbers.")
else:
  print(f"The factorial of {num} is {factorial(num)}")
# Out:
# Enter a non negative integer: 3
# The factorial of 3 is 6
