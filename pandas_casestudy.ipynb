# %% [markdown]
# <a href="https://colab.research.google.com/github/Devadetharu/Assignment3.ipynb/blob/main/pandas_casestudy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Import pandas, numpy

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 2. Load dataset using pd.read_csv()

# %%
df = pd.read_csv("https://raw.githubusercontent.com/laxmimerit/All-CSV-ML-Data-Files-Download/master/IMDB-Movie-Data.csv")
df
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # 3. Display: shape, head, column names, datatypes, missing value

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.head()
# Out:
#    Rank                    Title                     Genre  \
# 0     1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1     2               Prometheus  Adventure,Mystery,Sci-Fi
# 2     3                    Split           Horror,Thriller
# 3     4                     Sing   Animation,Comedy,Family
# 4     5            Suicide Squad  Action,Adventure,Fantasy
#
#                                          Description              Director  \
# 0  A group of intergalactic criminals are forced ...            James Gunn
# 1  Following clues to the origin of mankind, a te...          Ridley Scott
# 2  Three girls are kidnapped by a man with a diag...    M. Night Shyamalan
# 3  In a city of humanoid animals, a hustling thea...  Christophe Lourdelet
# 4  A secret government agency recruits some of th...            David Ayer
#
#                                               Actors  Year  Runtime (Minutes)  \
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Rank                    int64
# Title                  object
# Genre                  object
# Description            object
# Director               object
# Actors                 object
# Year                    int64
# Runtime (Minutes)       int64
# Rating                float64
# Votes                   int64
# Revenue (Millions)    float64
# Metascore             float64
# dtype: object

# %%
df.isnull().sum()
# Out:
# Rank                    0
# Title                   0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %% [markdown]
# # 4. Check and remove duplicates

# %%
df_remove = df.drop_duplicates()
df_remove
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # 5. Rename columns ("Title" > "Movie_Title")

# %%
df_remove = df_remove.rename(columns={'Title':'Movie_Title'})
df_remove
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # 6. Get unique genres

# %%
df_remove['Genre'].unique()
# Out:
# array(['Action,Adventure,Sci-Fi', 'Adventure,Mystery,Sci-Fi',
#        'Horror,Thriller', 'Animation,Comedy,Family',
#        'Action,Adventure,Fantasy', 'Comedy,Drama,Music', 'Comedy',
#        'Action,Adventure,Biography', 'Adventure,Drama,Romance',
#        'Adventure,Family,Fantasy', 'Biography,Drama,History',
#        'Animation,Adventure,Comedy', 'Action,Comedy,Drama',
#        'Action,Thriller', 'Biography,Drama', 'Drama,Mystery,Sci-Fi',
#        'Adventure,Drama,Thriller', 'Drama', 'Crime,Drama,Horror',
#        'Action,Adventure,Drama', 'Drama,Thriller',
#        'Action,Adventure,Comedy', 'Action,Horror,Sci-Fi',
#        'Adventure,Drama,Sci-Fi', 'Action,Adventure,Western',
#        'Comedy,Drama', 'Horror', 'Adventure,Drama,Fantasy',
#        'Action,Crime,Thriller', 'Action,Crime,Drama',
#        'Adventure,Drama,History', 'Crime,Horror,Thriller',
#        'Drama,Romance', 'Comedy,Drama,Romance', 'Horror,Mystery,Thriller',
# ...

# %% [markdown]
# # 7. Extract number of genres per movie

# %%
df_remove['Genre'].value_counts()
# Out:
# Genre
# Action,Adventure,Sci-Fi     50
# Drama                       48
# Comedy,Drama,Romance        35
# Comedy                      32
# Drama,Romance               31
#                             ..
# Drama,Fantasy,Musical        1
# Adventure,Family             1
# Adventure,Comedy,Fantasy     1
# Drama,Family,Music           1
# Comedy,Family,Fantasy        1
# Name: count, Length: 207, dtype: int64

# %% [markdown]
# # 8. Handle missing values in 'Revenue (Millions)' and 'Metascore'

# %%
df_remove['Revenue (Millions)'].isna().sum()
# Out:
# np.int64(128)

# %%
df_remove['Metascore'].isna().sum()
# Out:
# np.int64(64)

# %% [markdown]
# # 9. Top 5 movies by Rating

# %%
df_remove.nlargest(5,'Rating')
# Out:
#      Rank      Movie_Title                    Genre  \
# 54     55  The Dark Knight       Action,Crime,Drama
# 80     81        Inception  Action,Adventure,Sci-Fi
# 117   118           Dangal   Action,Biography,Drama
# 36     37     Interstellar   Adventure,Drama,Sci-Fi
# 96     97    Kimi no na wa  Animation,Drama,Fantasy
#
#                                            Description           Director  \
# 54   When the menace known as the Joker wreaks havo...  Christopher Nolan
# 80   A thief, who steals corporate secrets through ...  Christopher Nolan
# 117  Former wrestler Mahavir Singh Phogat and his t...      Nitesh Tiwari
# 36   A team of explorers travel through a wormhole ...  Christopher Nolan
# 96   Two strangers find themselves linked in a biza...     Makoto Shinkai
#
#                                                 Actors  Year  \
# 54   Christian Bale, Heath Ledger, Aaron Eckhart,Mi...  2008
# 80   Leonardo DiCaprio, Joseph Gordon-Levitt, Ellen...  2010
# ...

# %% [markdown]
# # 10. Movies with highest/lowest revenue

# %%
# Movie with highest revenue
df_remove.loc[df_remove['Revenue (Millions)'].idxmax()]
# Out:
# Rank                                                                 51
# Movie_Title                  Star Wars: Episode VII - The Force Awakens
# Genre                                          Action,Adventure,Fantasy
# Description           Three decades after the defeat of the Galactic...
# Director                                                    J.J. Abrams
# Actors                Daisy Ridley, John Boyega, Oscar Isaac, Domhna...
# Year                                                               2015
# Runtime (Minutes)                                                   136
# Rating                                                              8.1
# Votes                                                            661608
# Revenue (Millions)                                               936.63
# Metascore                                                          81.0
# Name: 50, dtype: object

# %%
# Movie with lowest revenue
df_remove.loc[df_remove['Revenue (Millions)'].idxmin()]
# Out:
# Rank                                                                232
# Movie_Title                                            A Kind of Murder
# Genre                                              Crime,Drama,Thriller
# Description           In 1960s New York, Walter Stackhouse is a succ...
# Director                                                   Andy Goddard
# Actors                Patrick Wilson, Jessica Biel, Haley Bennett, V...
# Year                                                               2016
# Runtime (Minutes)                                                    95
# Rating                                                              5.2
# Votes                                                              3305
# Revenue (Millions)                                                  0.0
# Metascore                                                          50.0
# Name: 231, dtype: object

# %% [markdown]
# # 11. Avg. rating by Director

# %%
df_remove.groupby('Director')['Rating'].mean()
# Out:
# Director
# Aamir Khan             8.50
# Abdellatif Kechiche    7.80
# Adam Leon              6.50
# Adam McKay             7.00
# Adam Shankman          6.30
#                        ...
# Xavier Dolan           7.55
# Yimou Zhang            6.10
# Yorgos Lanthimos       7.20
# Zack Snyder            7.04
# Zackary Adler          5.10
# Name: Rating, Length: 644, dtype: float64

# %% [markdown]
# # 12. Movies per year

# %%
df_remove.groupby('Year')['Movie_Title'].count()
# Out:
# Year
# 2006     44
# 2007     53
# 2008     52
# 2009     51
# 2010     60
# 2011     63
# 2012     64
# 2013     91
# 2014     98
# 2015    127
# 2016    297
# Name: Movie_Title, dtype: int64

# %% [markdown]
# # 13. Movies with rating > 8 & revenue > 100M

# %%
df_remove[(df_remove['Rating'] > 8) & (df_remove['Revenue (Millions)'] > 100)]
# Out:
#      Rank                                   Movie_Title  \
# 0       1                       Guardians of the Galaxy
# 6       7                                    La La Land
# 36     37                                  Interstellar
# 50     51    Star Wars: Episode VII - The Force Awakens
# 54     55                               The Dark Knight
# 67     68                            Mad Max: Fury Road
# 74     75                                      Zootopia
# 76     77                                  The Avengers
# 77     78                          Inglourious Basterds
# 80     81                                     Inception
# 82     83                       The Wolf of Wall Street
# 83     84                                     Gone Girl
# 92     93                                      The Help
# 99    100                                  The Departed
# 114   115  Harry Potter and the Deathly Hallows: Part 2
# 124   125                         The Dark Knight Rises
# ...

# %% [markdown]
# # 14. Group by Director: avg Rating, Revenue

# %%
df_remove.groupby('Director').agg(Avg_Rating = ('Rating','mean'),Avg_Revenue = ('Revenue (Millions)','mean'))
# Out:
#                      Avg_Rating  Avg_Revenue
# Director
# Aamir Khan                 8.50        1.200
# Abdellatif Kechiche        7.80        2.200
# Adam Leon                  6.50          NaN
# Adam McKay                 7.00      109.535
# Adam Shankman              6.30       78.665
# ...                         ...          ...
# Xavier Dolan               7.55        3.490
# Yimou Zhang                6.10       45.130
# Yorgos Lanthimos           7.20        4.405
# Zack Snyder                7.04      195.148
# Zackary Adler              5.10        6.530
#
# [644 rows x 2 columns]

# %% [markdown]
# # 15. Group by Year: count, avg Rating

# %%
df_remove.groupby('Year').agg(Movie_Count = ('Movie_Title', 'count'),Avg_Rating = ('Rating', 'mean'))
# Out:
#       Movie_Count  Avg_Rating
# Year
# 2006           44    7.125000
# 2007           53    7.133962
# 2008           52    6.784615
# 2009           51    6.960784
# 2010           60    6.826667
# 2011           63    6.838095
# 2012           64    6.925000
# 2013           91    6.812088
# 2014           98    6.837755
# 2015          127    6.602362
# 2016          297    6.436700

# %% [markdown]
# # 16. Create a new column Profitability:
#
# ###      a) Revenue divided by Duration

# %%
df_remove['Profitability'] =  df_remove['Revenue (Millions)'] / df_remove['Runtime (Minutes)']
df_remove
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# ### b) Find top 10 most profitable movies

# %%
df_remove.sort_values('Profitability', ascending = False).head(10)
# Out:
#      Rank                                 Movie_Title  \
# 50     51  Star Wars: Episode VII - The Force Awakens
# 85     86                              Jurassic World
# 119   120                                Finding Dory
# 87     88                                      Avatar
# 76     77                                The Avengers
# 15     16                     The Secret Life of Pets
# 688   689                                 Toy Story 3
# 12     13                                   Rogue One
# 174   175                                      Frozen
# 797   798                             Despicable Me 2
#
#                           Genre  \
# 50     Action,Adventure,Fantasy
# 85      Action,Adventure,Sci-Fi
# 119  Animation,Adventure,Comedy
# 87     Action,Adventure,Fantasy
# 76                Action,Sci-Fi
# 15   Animation,Adventure,Comedy
# 688  Animation,Adventure,Comedy
# 12      Action,Adventure,Sci-Fi
# 174  Animation,Adventure,Comedy
# 797  Animation,Adventure,Comedy
#
# ...

# %% [markdown]
# # 17. Create a column that categorizes movies by rating:
#
# ###       a) Rating < 6: Poor
#
# ###      b) 6 ≤ Rating < 7.5: Average
#
# ###       c) Rating ≥ 7.5: Excellent

# %%
def categorize(i):
  if i < 6:
    return 'Poor'
  elif i >= 6.5 and i < 7.5:
    return 'Average'
  else:
    return 'Excellent'

df_remove['Movie_Category'] = df_remove['Rating'].apply(categorize)
df_remove
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# # 18. Create a custom function to score movies based on:
#
# ###    i) Apply row['Rating'] * 10 + row['Revenue (Millions)'] as High score
# ### Apply a function to dataset to assign the score

# %%
def high_score(row):
  return row['Rating'] * 10 + row['Revenue (Millions)']

df_remove['High_score'] = df_remove.apply(high_score, axis = 1)
df_remove
# Out:
#      Rank              Movie_Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...
